# %%
recharge=int(input("Enter the recharge amount"))
if recharge==199:
    print("Recharge of 28 days")
elif recharge==299:
    print("Recharge of 56 days")
elif recharge==499:
    print("Recharge of 84 days")
else:
    print("Invalid recharge plan")
# Out:
# Enter the recharge amount 199
# Recharge of 28 days

# %%
recharge=int(input("Enter the recharge amount"))
if recharge==199:
    print("Recharge of 28 days")
elif recharge==299:
    print("Recharge of 56 days")
elif recharge==499:
    print("Recharge of 84 days")
else:
    print("Invalid recharge plan")
# Out:
# Enter the recharge amount 299
# Recharge of 56 days

# %%
recharge=int(input("Enter the recharge amount"))
if recharge==199:
    print("Recharge of 28 days")
elif recharge==299:
    print("Recharge of 56 days")
elif recharge==499:
    print("Recharge of 84 days")
else:
    print("Invalid recharge plan")
# Out:
# Enter the recharge amount 499
# Recharge of 84 days

# %%
recharge=int(input("Enter the recharge amount"))
if recharge==199:
    print("Recharge of 28 days")
elif recharge==299:
    print("Recharge of 56 days")
elif recharge==499:
    print("Recharge of 84 days")
else:
    print("Invalid recharge plan")
# Out:
# Enter the recharge amount 699
# Invalid recharge plan
