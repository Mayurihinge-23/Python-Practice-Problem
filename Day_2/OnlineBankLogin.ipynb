# %%
username = input("Enter Username: ")
print("Enter your password wisely. You have 3 attempts.")
password = input("Enter Password: ")

if password == "@1234":
    print("Login Successful")
else:
    print("Wrong Password! You have 2 attempts left.")

    password = input("Enter Password: ")
    if password == "@1234":
        print("Login Successful")
    else:
        print("Wrong Password! You have 1 attempt left.")

        password = input("Enter Password: ")
        if password == "@1234":
            print("Login Successful")
        else:
            print("Account temporarily locked.")
# Out:
# Enter Username:  mayuri
# Enter your password wisely. You have 3 attempts.
# Enter Password:  @1234
# Login Successful

# %%
username = input("Enter Username: ")
print("Enter your password wisely. You have 3 attempts.")
password = input("Enter Password: ")

if password == "@1234":
    print("Login Successful")
else:
    print("Wrong Password! You have 2 attempts left.")

    password = input("Enter Password: ")
    if password == "@1234":
        print("Login Successful")
    else:
        print("Wrong Password! You have 1 attempt left.")

        password = input("Enter Password: ")
        if password == "@1234":
            print("Login Successful")
        else:
            print("Account temporarily locked.")
# Out:
# Enter Username:  mayuri
# Enter your password wisely. You have 3 attempts.
# Enter Password:  1234
# Wrong Password! You have 2 attempts left.
# Enter Password:  @1234
# Login Successful

# %%
username = input("Enter Username: ")
print("Enter your password wisely. You have 3 attempts.")
password = input("Enter Password: ")

if password == "@1234":
    print("Login Successful")
else:
    print("Wrong Password! You have 2 attempts left.")

    password = input("Enter Password: ")
    if password == "@1234":
        print("Login Successful")
    else:
        print("Wrong Password! You have 1 attempt left.")

        password = input("Enter Password: ")
        if password == "@1234":
            print("Login Successful")
        else:
            print("Account temporarily locked.")
# Out:
# Enter Username:  mayuri
# Enter your password wisely. You have 3 attempts.
# Enter Password:  1234
# Wrong Password! You have 2 attempts left.
# Enter Password:  12344
# Wrong Password! You have 1 attempt left.
# Enter Password:  @1234
# Login Successful
