# %%
n=10
even=0
odd=0
for i in range(1,n+1):
    if i%2==0:
        even+=1
    else:
        odd+=1
print("even are:",even)
print("odd are:",odd)
# Out:
# even are: 5
# odd are: 5

# %%
n=int(input("Enter the number"))
even=0
odd=0
for i in range(1,n+1):
    if i%2==0:
        even+=1
    else:
        odd+=1
print("even are:",even)
print("odd are:",odd)
# Out:
# Enter the number 20
# even are: 10
# odd are: 10

# %%
n=int(input("Enter the number"))
even=0
odd=0
for i in range(1,n+1):
    if i%2==0:
        even+=1
    else:
        odd+=1
print("even are:",even)
print("odd are:",odd)
# Out:
# Enter the number 25
# even are: 12
# odd are: 13
