# %%
n=7
for i in range(7,71,7):
    print(i)
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70

# %%
n=7
for i in range(1,11):
    print(f"{n}*{i}={n*i}")
# Out:
# 7*1=7
# 7*2=14
# 7*3=21
# 7*4=28
# 7*5=35
# 7*6=42
# 7*7=49
# 7*8=56
# 7*9=63
# 7*10=70

# %%
n=int(input("Enter the number"))
for i in range(1,11):
    print(f"{n}*{i}={n*i}")
# Out:
# Enter the number 7
# 7*1=7
# 7*2=14
# 7*3=21
# 7*4=28
# 7*5=35
# 7*6=42
# 7*7=49
# 7*8=56
# 7*9=63
# 7*10=70
