# %%
n=10
sum=0
for i in range(1,11):
    sum=sum+i
print("Sum is:",sum)
# Out:
# Sum is: 55

# %%
n=int(input("Enter the number"))
sum=0
for i in range(1,11):
    sum=sum+i
print("Sum is:",sum)
# Out:
# Enter the number 10
# Sum is: 55
