# %%
Maths=int(input("Enter the marks:"))
Science=int(input("Enter the marks:"))
English=int(input("Enter the marks:"))
History=int(input("Enter the marks:"))
Computer=int(input("Enter the marks:"))
total=0
average=0
result=0
for i in range(1,6):
    total=Maths+Science+English+History+Computer
print("Total is :",total)
average=total/5
print("Average is:",average)
if Maths>=35 and Science>=35 and English>=35 and History>=35 and Computer>=35:
    print("Result=Pass")
else:
    print("Result=Fail")
# Out:
# Enter the marks: 78
# Enter the marks: 69
# Enter the marks: 81
# Enter the marks: 52
# Enter the marks: 91
# Total is : 371
# Average is: 74.2
# Result=Pass

# %%
Maths=int(input("Maths:"))
Science=int(input("Science:"))
English=int(input("English:"))
History=int(input("History:"))
Computer=int(input("Computer:"))
total=0
average=0
result=0
for i in range(1,6):
    total=Maths+Science+English+History+Computer
print("Total is :",total)
average=total/5
print("Average is:",average)
if Maths>=35 and Science>=35 and English>=35 and History>=35 and Computer>=35:
    print("Result=Pass")
else:
    print("Result=Fail")
# Out:
# Maths: 45
# Science: 85
# English: 42
# History: 63
# Computer: 74
# Total is : 309
# Average is: 61.8
# Result=Pass

# %%
Maths=int(input("Maths:"))
Science=int(input("Science:"))
English=int(input("English:"))
History=int(input("History:"))
Computer=int(input("Computer:"))
total=0
average=0
result=0
for i in range(1,6):
    total=Maths+Science+English+History+Computer
print("Total is :",total)
average=total/5
print("Average is:",average)
if Maths>=35 and Science>=35 and English>=35 and History>=35 and Computer>=35:
    print("Result=Pass")
else:
    print("Result=Fail")
# Out:
# Maths: 26
# Science: 45
# English: 28
# History: 78
# Computer: 45
# Total is : 222
# Average is: 44.4
# Result=Fail
