# %%
n=231
small=n%10          
while n>0:          
    d=n%10          
    if d<small:     
        small=d                                           
    n=n//10                                                   
print(f"smallest is:{small}")
# Out:
# smallest is:1

# %%
n=int(input("Enter the number"))
small=n%10          
while n>0:          
    d=n%10          
    if d<small:     
        small=d                                           
    n=n//10                                                   
print(f"smallest is:{small}")
# Out:
# Enter the number 451236
# smallest is:1
