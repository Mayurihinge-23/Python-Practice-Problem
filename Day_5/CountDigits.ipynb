# %%
n=input("Enter the number")
i=1
while i<=1:
    a=len(n)
    print(f"Total Digits:{a}")
    i=i+1
# Out:
# Enter the number 123456789
# Total Digits:9

# %%
n=input("Enter the number:")
i=1
while(i<=1):
    a=len(n)
    print(f"Total Digits:{a}")
    i=i+1
# Out:
# Enter the number: 1254
# Total Digits:4

# %%
n=input("Enter the number")
count=0
while n>0:
    n=n//10
    count=count+1
    print(f"Total Digits:{count}")
# Out:
# Enter the number 1234
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 n=input("Enter the number")
#       2 count=0
# ----> 3 while n>0:
#       4     n=n//10
#       5     count=count+1
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
n=int(input("Enter the number"))
count=0
while n>0:
    n=n//10
    count=count+1
print(f"Total Digits:{count}")
# Out:
# Enter the number 12345
# Total Digits:5

# %%
n=int(input("Enter the number"))
count=0
while n>0:
    n=n//10
    count=count+1
print(f"Total Digits:{count}")
# Out:
# Enter the number 456879123
# Total Digits:9
