# %%
n=1200330
zero=0
while n>0:
    d=n%10
    if d==0:
        zero+=1
    n=n//10
print(f"Zeros are:{zero}")
# Out:
# Zeros are:3

# %%
n=100200330
zero=0
while n>0:
    d=n%10
    if d==0:
        zero+=1
    n=n//10
print(f"Zeros are:{zero}")
# Out:
# Zeros are:5

# %%
n=int(input("enter the number"))

zero=0
while n>0:
    d=n%10
    if d==0:
        zero+=1
    n=n//10
print(f"Zeros are:{zero}")
# Out:
# enter the number 10201201230
# Zeros are:4
