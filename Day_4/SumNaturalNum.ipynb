# %%
n=7
sum=0
i=1
while i<=n:
    sum=sum+i
    i=i+1
print(sum)
# Out:
# 28

# %%
n=7
sum=0
i=1
while i<=n:
    sum=sum+i
    i=i+1
print(f"Sum is:{sum}")
# Out:
# Sum is:28

# %%
n=int(input("Enter the number:"))
sum=0
i=1
while i<=n:
    sum=sum+i
    i=i+1
print(f"Sum is:{sum}")
# Out:
# Enter the number: 7
# Sum is:28

# %%
n=int(input("Enter the number:"))
sum=0
i=1
while i<=n:
    sum=sum+i
    i=i+1
print(f"Sum is:{sum}")
# Out:
# Enter the number: 5
# Sum is:15

# %%
n=int(input("Enter the number:"))
sum=0
i=1
while i<=n:
    sum=sum+i
    i=i+1
print(f"Sum is:{sum}")
# Out:
# Enter the number: 10
# Sum is:55
