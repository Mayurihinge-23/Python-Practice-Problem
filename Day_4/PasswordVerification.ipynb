# %%
i=1
while(i<=1): #1<=1-true
    password=input("Enter the password:")
    if password=='@1234': #@1234==@1234 ->true
        print("Login Sucessful")
        break
    else:    
        print("Wrong password!")
# Out:
# Enter the password: 1234
# Wrong password!
# Enter the password: 1234
# Wrong password!
# Enter the password: @123
# Wrong password!
# Enter the password: @1234
# Login Sucessful

# %%
i=1
while(i<=1): #1<=1-true
    password=input("Enter the password:")
    if password=='@1234': #@1234==@1234 ->true
        print("Login Sucessful")
        break
    else:    
        print("Wrong password!")
# Out:
# Enter the password: @1234
# Login Sucessful
