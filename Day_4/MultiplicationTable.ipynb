# %%
n=5
i=1
while(i<=10):
    print(n*i)
    i=i+1
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
n=int(input("which number table you want? :"))
i=1
while(i<=10):
    mul=n*i
    print(f"{n}*{i}={mul}")
    i=i+1
# Out:
# which number table you want? : 4
# 4*1=4
# 4*2=8
# 4*3=12
# 4*4=16
# 4*5=20
# 4*6=24
# 4*7=28
# 4*8=32
# 4*9=36
# 4*10=40

# %%
n=int(input("which number table you want? :"))
i=1
while(i<=10):
    mul=n*i
    print(f"{n}*{i}={mul}")
    i=i+1
# Out:
# which number table you want? : 7
# 7*1=7
# 7*2=14
# 7*3=21
# 7*4=28
# 7*5=35
# 7*6=42
# 7*7=49
# 7*8=56
# 7*9=63
# 7*10=70
