# %%
n=5
marks=n
for i in range(1,n+1):
    sub=int(input(f"Enter the Student{i}:"))
    if sub>90 or sub>100:
        print(f"Student {i}:{sub} \nGrade:A")
    elif sub>75 or sub>89:
        print(f"Student {i}:{sub} \nGrade:B") 
    elif sub>60 or sub>74:
        print(f"Student {i}:{sub} \nGrade:C")  
    elif sub>35 or sub>59:
        print(f"Student {i}:{sub} \nGrade:D")
    else:
        print(f"Student {i}:{sub} \nFail")
# Out:
# Enter the Student1: 77
# Student 1:77
# Grade:B
# Enter the Student2: 96
# Student 2:96
# Grade:A
# Enter the Student3: 55
# Student 3:55
# Grade:D
# Enter the Student4: 85
# Student 4:85
# Grade:B
# Enter the Student5: 20
# Student 5:20
# Fail

# %%
n=int(input("Enter the nuber of student?:"))
for i in range(1,n+1):
    sub=int(input(f"Enter the Student{i}:"))
    if sub>90 or sub>100:
        print(f"Student {i}:{sub} \nGrade:A")
    elif sub>75 or sub>89:
        print(f"Student {i}:{sub} \nGrade:B") 
    elif sub>60 or sub>74:
        print(f"Student {i}:{sub} \nGrade:C")  
    elif sub>35 or sub>59:
        print(f"Student {i}:{sub} \nGrade:D")
    else:
        print(f"Student {i}:{sub} \nFail")
# Out:
# Enter the nuber of student?: 3
# Enter the Student1: 85
# Student 1:85
# Grade:B
# Enter the Student2: 74
# Student 2:74
# Grade:C
# Enter the Student3: 99
# Student 3:99
# Grade:A
