# %%
n=10
lar=n
small=n
for i in range(1,n+1):
    num=int(input(f"Enter the number{i}:"))
    if num>lar:
        lar=num
    else:
        small=num
print("largest:",lar)        
print("smallest:",small)
# Out:
# Enter the number1: 45
# Enter the number2: 78
# Enter the number3: 95
# Enter the number4: 54
# Enter the number5: 12
# Enter the number6: 10
# Enter the number7: 23
# Enter the number8: 11
# Enter the number9: 45
# Enter the number10: 0
# largest: 95
# smallest: 0

# %%
n=int(input("Enter the number"))
lar=n
small=n
for i in range(1,n+1):
    num=int(input(f"Enter the number{i}:"))
    if num>lar:
        lar=num
    else:
        small=num
print("largest:",lar)        
print("smallest:",small)
# Out:
# Enter the number 5
# Enter the number1: 4
# Enter the number2: 6
# Enter the number3: 78
# Enter the number4: 92
# Enter the number5: 100
# largest: 100
# smallest: 4

# %%
n=int(input("Enter the number"))
lar=n
small=n
for i in range(1,n+1):
    num=int(input(f"Enter the number{i}:"))
    if num>lar:
        lar=num
    if num<small:
        small=num
print("largest:",lar)        
print("smallest:",small)
# Out:
# Enter the number 5
# Enter the number1: 3
# Enter the number2: 4
# Enter the number3: 45
# Enter the number4: 1
# Enter the number5: 84
# largest: 84
# smallest: 1

# %%
n=int(input("Enter the number"))
lar=n
small=n
for i in range(1,n+1):
    num=int(input(f"Enter the number{i}:"))
    if num>lar:
        lar=num
    else:
        small=num
print("largest:",lar)        
print("smallest:",small)
# Out:
# Enter the number 3
# Enter the number1: 54
# Enter the number2: 46
# Enter the number3: 3
# largest: 54
# smallest: 3

# %%
n=int(input("Enter the number"))
lar=n
small=n
for i in range(1,n+1):
    num=int(input(f"Enter the number{i}:"))
    if num>lar:
        lar=num
    else:
        small=num
print("largest:",lar)        
print("smallest:",small)
# Out:
# Enter the number 3
# Enter the number1: 2
# Enter the number2: 45
# Enter the number3: 3
# largest: 45
# smallest: 3

# %%
n=int(input("Enter the number"))
lar=n
small=n
for i in range(1,n+1):
    num=int(input(f"Enter the number{i}:"))
    if num>lar:
        lar=num
    if num<small:
        small=num
print("largest:",lar)        
print("smallest:",small)
# Out:
# Enter the number 3
# Enter the number1: 2
# Enter the number2: 45
# Enter the number3: 3
# largest: 45
# smallest: 2
