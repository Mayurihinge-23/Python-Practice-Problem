# %%
n=7
for i in range(10,0,-1):
    print(f"{n}*{i}={n*i}")
# Out:
# 7*10=70
# 7*9=63
# 7*8=56
# 7*7=49
# 7*6=42
# 7*5=35
# 7*4=28
# 7*3=21
# 7*2=14
# 7*1=7

# %%
n=int(input("Enter the number"))
for i in range(10,0,-1):
    print(f"{n}*{i}={n*i}")
# Out:
# Enter the number 5
# 5*10=50
# 5*9=45
# 5*8=40
# 5*7=35
# 5*6=30
# 5*5=25
# 5*4=20
# 5*3=15
# 5*2=10
# 5*1=5

# %%
n=int(input("Enter the number"))
for i in range(10,0,-1):
    print(f"{n}*{i}={n*i}")
# Out:
# Enter the number 7
# 7*10=70
# 7*9=63
# 7*8=56
# 7*7=49
# 7*6=42
# 7*5=35
# 7*4=28
# 7*3=21
# 7*2=14
# 7*1=7
