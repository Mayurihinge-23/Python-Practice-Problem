# %%
n=12
even=0
odd=0

for i in range(1,n+1):
   
    if i%2==0:
        even=even+i
    else:
        odd=odd+i    
print("even",even)
print("odd",odd)
# Out:
# even 42
# odd 36

# %%
n=10
even=0
odd=0

for i in range(1,n+1):
   
    if i%2==0:
        even=even+i
    else:
        odd=odd+i    
print("even",even)
print("odd",odd)
# Out:
# even 30
# odd 25

# %%
n=int(input("Enter the number:"))
even=0
odd=0
for i in range(1,n+1):
    if i%2==0:
        even+=1
    else:
        odd+=1
print("Even:",even)
print("Odd:",odd)
# Out:
# Enter the number: 4
# Even: 2
# Odd: 2

# %%
n=int(input("Enter the number:"))
even=0
odd=0
for i in range(1,n+1):
    if i%2==0:
        even+=1
    else:
        odd+=1
print("Even:",even)
print("Odd:",odd)
# Out:
# Enter the number: 10
# Even: 5
# Odd: 5
