# %%
#for 5 attempt
n=25
for i in range(1,6):
    guess=int(input("Guess the number"))
    if guess==n:
        print("Congratulations")
        break
    else:
        print("Game over")
    print("Sorry! Try next time")
# Out:
# Guess the number 46
# Game over
# Sorry! Try next time
# Guess the number 23
# Game over
# Sorry! Try next time
# Guess the number 15
# Game over
# Sorry! Try next time
# Guess the number 25
# Congratulations

# %%
n=25
for i in range(1,6):
    guess=int(input("Guess the number"))
    if guess==n:
        print("Congratulations")
        break
    else:
        print("Game over")
    print("Sorry! Try next time")
# Out:
# Guess the number 25
# Congratulations

# %%
num=25
for i in range(1,n+1):
    guess=int(input("Guess the number"))
    if guess==num:
        print("Congratulations")
        break
    else:
        print("Game over")
    print("Sorry! Try next time")
# Out:
# Guess the number 45
# Game over
# Sorry! Try next time
# Guess the number 12
# Game over
# Sorry! Try next time
# Guess the number 1
# Game over
# Sorry! Try next time
# Guess the number 25
# Congratulations

# %%
num=5
for i in range(1,n+1):
    guess=int(input("Guess the number"))
    if guess==num:
        print("Congratulations")
        break
    else:
        print("Game over")
    print("Sorry! Try next time")
# Out:
# Guess the number 4
# Game over
# Sorry! Try next time
# Guess the number 1
# Game over
# Sorry! Try next time
# Guess the number 3
# Game over
# Sorry! Try next time
# Guess the number 6
# Game over
# Sorry! Try next time
# Guess the number 8
# Game over
# Sorry! Try next time
# Guess the number 1
# Game over
# Sorry! Try next time
# Guess the number 7
# Game over
# Sorry! Try next time
# Guess the number 5
# Congratulations
