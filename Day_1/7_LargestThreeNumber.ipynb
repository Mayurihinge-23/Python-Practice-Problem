# %%
num1=int(input("Enter the num1:"))
num2=int(input("Enter the num2:"))
num3=int(input("Enter the num3:"))
if(num1>num2 and num1>num3):
    print(f"{num1} is greather")
elif(num2>num3):
    print(f"{num2} is greather")
else:
    print(f"{num3} is greather")
# Out:
# Enter the num1: 56
# Enter the num2: 45
# Enter the num3: 78
# 78 is greather

# %%
num1=int(input("Enter the num1:"))
num2=int(input("Enter the num2:"))
num3=int(input("Enter the num3:"))
if(num1>num2 and num1>num3):
    print(f"{num1} is greather")
elif(num2>num3):
    print(f"{num2} is greather")
else:
    print(f"{num3} is greather")
# Out:
# Enter the num1: 87
# Enter the num2: 65
# Enter the num3: 12
# 87 is greather

# %%
num1=int(input("Enter the num1:"))
num2=int(input("Enter the num2:"))
num3=int(input("Enter the num3:"))
if(num1>num2 and num1>num3):
    print(f"{num1} is greather")
elif(num2>num3):
    print(f"{num2} is greather")
else:
    print(f"{num3} is greather")
# Out:
# Enter the num1: 23
# Enter the num2: 56
# Enter the num3: 41
# 56 is greather
