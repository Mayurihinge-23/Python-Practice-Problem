# %%
age=int(input("Enter the age:"))
if(age>=18):
    print(f"Age is {age}.You are eligible for Voting")
else:
    print(f"Age is {age}.You are not eligible for Voting")
# Out:
# Enter the age: 15
# Age is 15.You are not eligible for Voting

# %%
age=int(input("Enter the age:"))
if(age>=18):
    print(f"Age is {age}.You are eligible for Voting")
else:
    print(f"Age is {age}.You are not eligible for Voting")
# Out:
# Enter the age: 22
# Age is 22.You are eligible for Voting
