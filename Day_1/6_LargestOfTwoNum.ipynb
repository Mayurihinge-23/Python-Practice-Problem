# %%
num1=int(input("Enter the num1:"))
num2=int(input("Enter the num2:"))
if(num1>num2):
    print(f"{num1} is greather than {num2}")
else:
    print(f"{num2} is greather than {num1}")
# Out:
# Enter the num1: 65
# Enter the num2: 23
# 65 is greather than 23

# %%
num1=int(input("Enter the num1:"))
num2=int(input("Enter the num2:"))
if(num1>num2):
    print(f"{num1} is greather than {num2}")
else:
    print(f"{num2} is greather than {num1}")
# Out:
# Enter the num1: 66
# Enter the num2: 89
# 89 is greather than 66
