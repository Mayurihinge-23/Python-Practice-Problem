# %%
num=int(input("Enter the number:"))
if(num==0):
    print(f"{num} is Zero")
elif(num>0):
    print(f"{num} is Positive")
else:
    print(f"{num} is Negative")
# Out:
# Enter the number: -1
# -1 is Negative

# %%
num=int(input("Enter the number:"))
if(num==0):
    print(f"{num} is Zero")
elif(num>0):
    print(f"{num} is Positive")
else:
    print(f"{num} is Negative")
# Out:
# Enter the number: 6
# 6 is Positive

# %%
num=int(input("Enter the number:"))
if(num==0):
    print(f"{num} is Zero")
elif(num>0):
    print(f"{num} is Positive")
else:
    print(f"{num} is Negative")
# Out:
# Enter the number: 0
# 0 is Zero
