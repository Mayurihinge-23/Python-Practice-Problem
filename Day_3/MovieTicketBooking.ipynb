# %%
age=int(input("Enter the age"))
show=input("When you want show (Morning/Evening):")
student=input("Are you student? (Yes/No):")
price=299
if student=='Yes':
    print("You have discount of 10%")
    dis=price*0.10
    final=price-dis
    print(f"Your total final ticket is :{final}")
else:
    print("no discount")
# Out:
# Enter the age 25
# When you want show (Morning/Evening): morning
# Are you student? (Yes/No): No
# no discount

# %%
age=int(input("Enter the age"))
show=input("When you want show (Morning/Evening):")
student=input("Are you student? (Yes/No):")
price=299
if student=='Yes':
    print("You have discount of 10%")
    dis=price*0.10
    final=price-dis
    print(f"Your total final ticket is :{final}")
else:
    print("no discount")
# Out:
# Enter the age 25
# When you want show (Morning/Evening): Evening
# Are you student? (Yes/No): Yes
# You have discount of 10%
# Your total final ticket is :269.1
