# %%
percentage=int(input("Enter the percentage:"))
income=int(input("Enter the income:"))
if percentage>=90 and income<300000:
    print("you have 100% scholarship")
elif percentage>=80 and income<500000:
    print("you have 50% scholarship")    
elif percentage>=70:
    print("you have 25% scholarship")
else:   
    print("No Scholarship")
# Out:
# Enter the percentage: 65
# Enter the income: 50000
# No Scholarship

# %%
percentage=int(input("Enter the percentage:"))
income=int(input("Enter the income:"))
if percentage>=90 and income<300000:
    print("you have 100% scholarship")
elif percentage>=80 and income<500000:
    print("you have 50% scholarship")    
elif percentage>=70:
    print("you have 25% scholarship")
else:   
    print("No Scholarship")
# Out:
# Enter the percentage: 85
# Enter the income: 50000
# you have 50% scholarship

# %%
percentage=int(input("Enter the percentage:"))
income=int(input("Enter the income:"))
if percentage>=90 and income<300000:
    print("you have 100% scholarship")
elif percentage>=80 and income<500000:
    print("you have 50% scholarship")    
elif percentage>=70:
    print("you have 25% scholarship")
else:   
    print("No Scholarship")
# Out:
# Enter the percentage: 95
# Enter the income: 50000
# you have 100% scholarship
