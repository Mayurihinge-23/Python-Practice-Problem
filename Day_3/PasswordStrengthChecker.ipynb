# %%
password=input("Enter the password")
if len(password)>=8 and "@" in password:
    print("strong password")
else:
    print("weak password")
# Out:
# Enter the password 1234564
# weak password

# %%
password=input("Enter the password")
if len(password)>=8 and "@" in password:
    print("strong password")
else:
    print("weak password")
# Out:
# Enter the password Mayu1234
# weak password

# %%
password=input("Enter the password")
if len(password)>=8 and "@" in password:
    print("strong password")
else:
    print("weak password")
# Out:
# Enter the password @Mayu123
# strong password
