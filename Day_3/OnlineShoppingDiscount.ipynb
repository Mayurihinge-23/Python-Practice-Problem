# %%
Purchase_Amt=int(input("Shopping amount: Rs."))
premium=input("Are you premium customer (Yes/No):")
if Purchase_Amt>=5000: #6000>=5000 -> true
    print("Congratulation ! You have 20% of discount")
    if premium=='Yes': #Yes
        print("A Big Congratulation!! You win the 5% extra discount")
        dis=Purchase_Amt*0.25
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
    else:
        dis=Purchase_Amt*0.20
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
if Purchase_Amt<=3000 or  Purchase_Amt<4000 :       
    print("Congratulation ! You have 10% of discount")
    if premium=='Yes':   
        print("A Big Congratulation!! You win the 5% extra discount")
        dis=Purchase_Amt*0.15
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
    else:
        dis=Purchase_Amt*0.10
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}")   
else:
    print(f"Thank you! \nVisit Again!!")
# Out:
# Shopping amount: Rs. 6000
# Are you premium customer (Yes/No): Yes
# Congratulation ! You have 20% of discount
# A Big Congratulation!! You win the 5% extra discount
# You Final Amount is: Rs.4500.0
# Thank you!
# Visit Again!!

# %%
Purchase_Amt=int(input("Shopping amount: Rs."))
premium=input("Are you premium customer (Yes/No):")
if Purchase_Amt>=5000: #6000>=5000
    print("Congratulation ! You have 20% of discount")
    if premium=='Yes':
        print("A Big Congratulation!! You win the 5% extra discount")
        dis=Purchase_Amt*0.25
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
    else: #No
        dis=Purchase_Amt*0.20
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
if Purchase_Amt<=3000 or  Purchase_Amt<4000 :       
    print("Congratulation ! You have 10% of discount")
    if premium=='Yes':   
        print("A Big Congratulation!! You win the 5% extra discount")
        dis=Purchase_Amt*0.15
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
    else:
        dis=Purchase_Amt*0.10
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}")   
else:
    print(f"Thank you! \nVisit Again!!")
# Out:
# Shopping amount: Rs. 6000
# Are you premium customer (Yes/No): No
# Congratulation ! You have 20% of discount
# You Final Amount is: Rs.4800.0
# Thank you!
# Visit Again!!

# %%
Purchase_Amt=int(input("Shopping amount: Rs."))
premium=input("Are you premium customer (Yes/No):")
if Purchase_Amt>=5000: 
    print("Congratulation ! You have 20% of discount")
    if premium=='Yes':
        print("A Big Congratulation!! You win the 5% extra discount")
        dis=Purchase_Amt*0.25
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
    else: #No
        dis=Purchase_Amt*0.20
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
if Purchase_Amt<=3000 or  Purchase_Amt<4000 :  #3500<=3000 ->false or 3500<4000->true    
    print("Congratulation ! You have 10% of discount")
    if premium=='Yes':   #(Yes)
        print("A Big Congratulation!! You win the 5% extra discount")
        dis=Purchase_Amt*0.15
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
    else:
        dis=Purchase_Amt*0.10
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}")   
else:
    print(f"Thank you! \nVisit Again!!")
# Out:
# Shopping amount: Rs. 3500
# Are you premium customer (Yes/No): Yes
# Congratulation ! You have 10% of discount
# A Big Congratulation!! You win the 5% extra discount
# You Final Amount is: Rs.2975.0

# %%
Purchase_Amt=int(input("Shopping amount: Rs."))
premium=input("Are you premium customer (Yes/No):")
if Purchase_Amt>=5000: 
    print("Congratulation ! You have 20% of discount")
    if premium=='Yes':
        print("A Big Congratulation!! You win the 5% extra discount")
        dis=Purchase_Amt*0.25
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
    else: #No
        dis=Purchase_Amt*0.20
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
if Purchase_Amt<=3000 or  Purchase_Amt<=4000 :  #3500<=3000 ->false or 3500<=4000->true    
    print("Congratulation ! You have 10% of discount")
    if premium=='Yes':   
        print("A Big Congratulation!! You win the 5% extra discount")
        dis=Purchase_Amt*0.15
        Final_amt=Purchase_Amt-dis
        print(f"You Final Amount is: Rs.{Final_amt}") 
    else:
        dis=Purchase_Amt*0.10
        Final_amt=Purchase_Amt-dis
        print(f"Your Final Amount is: Rs.{Final_amt}")   
else:
    print(f"Thank you! \nVisit Again!!")
# Out:
# Shopping amount: Rs. 3500
# Are you premium customer (Yes/No): No
# Congratulation ! You have 10% of discount
# Your Final Amount is: Rs.3150.0
